# %% [markdown]
# <a href="https://colab.research.google.com/github/Suhyun77/Algorithm-and-Data-Structure/blob/main/%EA%B5%AC%ED%98%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **구현 : 시뮬레이션과 완전 탐색**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 2차원 공간과 관련된 문제가 많다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **완전 탐색** : 모든 경우의 수를 주저 없이 다 계산하는 해결 방법
# - **시뮬레이션** : 문제에서 제시한 알고리즘을 한 단계씩 차례대로 직접 수행해야 하는 문제 유형

# %% [markdown]
# ## **[문제1] 상하 좌우**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# N 입력받기
n = int(input())
x, y = 1, 1
plans = input().split()


# L, R, U, D에 따른 이동 방향 (x와 y 따로 구하기)
dx = [0, 0, -1, 1]
dy = [-1, 1, 0, 0]
move_types = ['L', 'R', 'U', 'D']

# 이동 계획을 하나씩 확인
for plan in plans:
    # 이동 후 좌표 구하기
    for i in range(len(move_types)):
        if plan == move_types[i]:
            nx = x + dx[i]
            ny = y + dy[i]
    # 공간을 벗어나는 경우 무시
    if nx < 1 or ny < 1 or nx > n or ny > n:
        continue
    # 이동 수행
    x, y = nx, ny

print(x, y)
# Out:
# 5
# R R R U D D
# 3 4

# %% [markdown]
# - 문제 해설
#   - 시간 복잡도 : $O(N)$
#   - 연산 횟수가 이동 횟수에 비례하게 되므로
#   - 일련의 명령에 따라 개체를 이동시키므로 "시뮬레이션 유형"

# %% [markdown]
# ## **[문제2] 시각**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# H를 입력받기
h = int(input())

count = 0
for i in range(h + 1):  # 시
    for j in range(60):  # 분
        for k in range(60):  # 초
            # 매 시각 안에 '3'이 포함되어 있다면 카운트 증가
            if '3' in str(i) + str(j) + str(k):
                count += 1

print(count)

# %% [markdown]
# ## **[문제3] 왕실의 나이트**

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 현재 나이트의 위치 입력받기
input_data = input()
row = int(input_data[1])
column = int(ord(input_data[0])) - int(ord('a')) + 1  # 아스키 코드

# 나이트가 이동할 수 있는 8가지 방향 정의
steps = [(-2, -1), (-1, -2), (1, -2), (2, -1), (2, 1), (1, 2), (-1, 2), (-2, 1)]

# 8가지 방향에 대하여 각 위치로 이동이 가능한지 확인
result = 0
for step in steps:
    # 이동하고자 하는 위치 확인
    next_row = row + step[0]
    next_column = column + step[1]
    # 해당 위치로 이동이 가능하다면 카운트 증가
    if next_row >= 1 and next_row <= 8 and next_column >= 1 and next_column <= 8:
        result += 1

print(result)

# %% [markdown]
# ## **[문제4] 문자열 재정렬**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %%time

# 각 char별로 입력받아 리스트에 입력
s = list(input())

sum = 0
char_list = []

for i in s:
    try:
        if int(i) >= 0:
            sum += int(i)
    except:
        char_list.append(i)

result = ''
char_list.sort()
for i in char_list:
    result += i
num = str(sum)

print(result+num)
# Out:
# K1KA5CB7
# ABCKK13
# CPU times: user 21.5 ms, sys: 838 µs, total: 22.3 ms
# Wall time: 3.54 s

# %%
# %%time

data = input()
result = []
value = 0

# 문자를 하나씩 확인하며
for x in data:
    # 알파벳인 경우 결과 리스트에 삽입
    if x.isalpha():
        result.append(x)
    # 숫자는 따로 더하기
    else:
        value += int(x)

# 알파벳을 오름차순으로 정렬
result.sort()

# 숫자가 하나라도 존재하는 경우 가장 뒤에 삽입  => 숫자가 없을 경우 0이 포함될 수 있으므로 주의
if value != 0:
    result.append(str(value))

# 최종 결과 출력(리스트를 문자열로 변환하여 출력)
print(''.join(result))
# Out:
# K1KA5CB7
# ABCKK13
# CPU times: user 11.5 ms, sys: 2.81 ms, total: 14.3 ms
# Wall time: 2.41 s

# %% [markdown]
# ## **[문제5] 게임 개발**

# %% [markdown]
# - 전형적인 시뮬레이션 문제

# %%
array = []
for i in range(4):
    array.append(list(map(int, input().split())))
# Out:
# 1 1 1 1
# 1 0 0 1
# 1 1 0 1
# 1 1 1 1

# %%
print(array)
# Out:
# [[1, 1, 1, 1], [1, 0, 0, 1], [1, 1, 0, 1], [1, 1, 1, 1]]

# %%
# N, M을 공백을 기준으로 구분하여 입력받기
n, m = map(int, input().split())

# 방문한 위치를 저장하기 위한 맵을 생성하여 0으로 초기화
d = [[0] * m for _ in range(n)]   # [[],[],[],[],...,[]]

# 현재 캐릭터의 X 좌표, Y 좌표, 방향을 입력받기
x, y, direction = map(int, input().split())
d[x][y] = 1 # 현재 좌표 방문 처리

# 전체 맵 정보를 입력받기
array = []
for i in range(n):
    array.append(list(map(int, input().split())))  # [[1, 1, 1, 1], [1, 0, 0, 1], [1, 1, 0, 1], [1, 1, 1, 1]]

# 북, 동, 남, 서 방향 정의
dx = [-1, 0, 1, 0]
dy = [0, 1, 0, -1]

# 왼쪽으로 회전
def turn_left():
    global direction  # 함수 바깥에서 선언된 전역변수이므로 global 사용
    direction -= 1  # 서쪽
    if direction == -1:
        direction = 3

# 시뮬레이션 시작
count = 1
turn_time = 0
while True:
    # 왼쪽으로 회전
    turn_left()
    nx = x + dx[direction]
    ny = y + dy[direction]
    # 회전한 이후 정면에 가보지 않은 칸이 존재하는 경우 이동
    if d[nx][ny] == 0 and array[nx][ny] == 0:
        d[nx][ny] = 1
        x = nx
        y = ny
        count += 1
        turn_time = 0
        continue
    # 회전한 이후 정면에 가보지 않은 칸이 없거나 바다인 경우
    else:
        turn_time += 1
    # 네 방향 모두 갈 수 없는 경우
    if turn_time == 4:
        nx = x - dx[direction]
        ny = y - dy[direction]
        # 뒤로 갈 수 있다면 이동하기
        if array[nx][ny] == 0:
            x = nx
            y = ny
        # 뒤가 바다로 막혀있는 경우
        else:
            break
        turn_time = 0

# 정답 출력
print(count)

# %% [markdown]
# ## **[문제6] [분산처리](https://www.acmicpc.net/problem/1009)**
#
# - 거듭제곱 : `**`
# - 시간초과되지 않으려면 최대한 거듭제곱 연산을 피하는 방식을 택해야 한다.

# %%
# 시간 초과
T = int(input())

for i in range(T):
    a, b = map(int, input().split())
    n_data = a**b
    print(str(n_data)[-1])
# Out:
# 5
# 1 6
# 1
# 3 7
# 7
# 6 2
# 6
# 7 100
# 1
# 9 635
# 9

# %%
# “에라토스테네스의 체” 개념

import sys
data_cnt = int(sys.stdin.readline())
for _ in range(data_cnt):
    a, b = map(int, sys.stdin.readline().split())
    """
    일의 자리 수는 최대 4개의 숫자 묶음으로 반복되므로
    a를 1부터 4까지 제곱한 수의 1의자리 집합 리스트를 만든뒤
    인덱스값이므로 b를 4로 나눈 나머지에서 1을 뺀 값으로 a리스트에서 일의 자리 숫자를 뽑아온다.
    다만, result값이 0이라는 것은 10의 배수임을 뜻하므로 이는 10을 출력하도록 조건을 걸어준다.
    """
    result = [(a ** i) % 10 for i in range(1,5)][(b % 4) -1]
    print(result if result != 0 else 10)

# %%
N = int(input())
# a의 b 제곱값의 1의 자리 수의 패턴 저장
array = [[0], [1], [2, 4, 8, 6], [3, 9, 7, 1], [4, 6, 4, 6], [5], [6], [7, 9, 3, 1], [8, 4, 2, 6], [9, 1, 9, 1]]

for _ in range(N):
    # a, b값 입력 받음
    a, b = map(int, input().split())

    # a가 10의 배수일 경우, 10 출력
    if a % 10 == 0:
        print(10)
        continue

    # a % 10이 1, 5, 6일 경우, a % 10 값 출력
    elif a % 10 == 1 or a % 10 == 5 or a % 10 == 6:
        print(a % 10)
        continue

    # b가 0이면 1 출력
    if b == 0:
        print(1)
        
    # b % 4가 0이면, array에 저장해둔 패턴값 가져옴
    elif b % 4 == 0:
        print(array[a % 10][3])
    else:
        print(array[a % 10][b % 4 - 1])

# %%
t = int(input())
a = []
b = []

# for문으로 t만큼 돌면서 a와 b를 입력받아 리스트에 저장한다.
for _ in range(t):
    num1, num2 = map(int, input().split())
    a.append(num1)
    b.append(num2)

for i in range(t):
	# a의 1의 자리수를 com 변수에 대입
    com = a[i] % 10
    
    # a가 10의 배수면, 바로 10번 컴퓨터에 매칭
    if com == 0:
        print(10)
    # a의 1의 자리수가 1, 5, 6이면, 그대로 출력하면 됨
    elif com in [1, 5, 6]:
        print(com)
    # a의 1의 자리수가 4, 9이면, b제곱한 수의 1의 자리수가 2가지 경우가 있음
    elif com in [4, 9]:
        if b[i] % 2 == 0:
            print(com ** 2 % 10)
        else:
            print(com)
    # a의 1의 자리수가 2, 3, 7, 8이면, b제곱한 수의 1의 자리수가 4가지 경우가 있음
    else:
        if b[i] % 4 == 0:
            print(com ** 4 % 10)
        else:
            print(com ** (b[i] % 4) % 10)

# %% [markdown]
# ## **[문제7] [소용돌이 예쁘게 출력하기](https://www.acmicpc.net/problem/1022)**

# %% [markdown]
# - 메모리 초과 : $(r_1, r_2, c_1, c_2의 최댓값) * 2 +1$의 소용돌이
# - 소용돌이를 돌며 지정된 부분만큼 배열을 만든 뒤 해당 부분에 도달할 때만 배열에 저장

# %%
dx = [1, 0, -1, 0]
dy = [0, 1, 0, -1]

r1, c1, r2, c2 = map(int, input().split())

board = [[0]*(c2-c1+1) for _ in range(r2-r1+1)]  # r2-r1+1 : 행 / c2-c1+1 : 열
num_board = (c2-c1+1) * (r2-r1+1)

y = x = 0
num = 1
cnt = 0  # 한 방향에서 움직이는 횟수
dcnt = 0  # 한 방향에서 움직여야 할 횟수
d = 0

# while문을 통해 소용돌이 그리기
while num_board > 0:
    if r1 <= y <= r2 and c1 <= x <= c2:
        num_board -= 1
        board[y-r1][x-c1] = num
        max_num = num
    num += 1
    cnt += 1

    # 방향 이동
    y = y + dy[d]
    x = x + dx[d]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-848b6f823339> in <module>()
#       3
#       4 start = time.time()
# ----> 5 input = sys.stdin.readine
#       6 r1, c1, r2, c2 = map(int, input().split())
#       7
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'readine'
